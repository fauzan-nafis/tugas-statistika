# %% [markdown]
# <a href="https://colab.research.google.com/github/fauzan-nafis/tugas-statistika/blob/main/TugasStratifiedrandomsamling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Stratified Random Sampling by Genre dan Estimasi Rata-rata populasi Budget film
# nama Fauzan nafis rofy 25090015/2A

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

movie = pd.read_csv('/content/MovieData-2018-2020.csv')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274 entries, 0 to 273
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      274 non-null    object
#  1   rating    268 non-null    object
#  2   genre     274 non-null    object
#  3   year      274 non-null    int64
#  4   released  274 non-null    object
#  5   score     271 non-null    float64
#  6   votes     271 non-null    float64
#  7   director  274 non-null    object
#  8   writer    274 non-null    object
#  9   star      274 non-null    object
#  10  country   273 non-null    object
#  11  budget    274 non-null    float64
#  12  gross     265 non-null    float64
#  13  company   271 non-null    object
#  14  runtime   273 non-null    float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 32.2+ KB

# %% [markdown]
# BERDASARKAN GENRe

# %%
genre_counts = movie["genre"].value_counts()
valid_genre = genre_counts[genre_counts >= 2].index
movie_clean = movie[movie["genre"].isin(valid_genre)]

_, stratified_sample = train_test_split(
    movie_clean,
    test_size=0.3,                       # Ambil 30% data dari setiap genre
    stratify=movie_clean["genre"],       # Stratifikasi berdasarkan kolom 'genre'
    random_state=15                      #  belakang nim
)

print("\nStratified Sampling:\n", stratified_sample)
print("\nJumlah sample per genre:\n", stratified_sample["genre"].value_counts())
# Out:
# Stratified Sampling:
#                                      name rating      genre  year  \
# 10         Mission: Impossible - Fallout  PG-13     Action  2018
# 114                  On the Basis of Sex  PG-13  Biography  2018
# 24                        A Star Is Born      R      Drama  2018
# 210                        Captive State  PG-13     Action  2019
# 183                          Toy Story 4      G  Animation  2019
# ..                                   ...    ...        ...   ...
# 251                            Overcomer     PG      Drama  2019
# 146              Fighting with My Family  PG-13  Biography  2019
# 51                            Robin Hood  PG-13     Action  2018
# 134  The Death & Life of John F. Donovan      R      Drama  2018
# 75                                Mid90s      R     Comedy  2018
#
#                               released  score     votes  \
# 10       July 27, 2018 (United States)    7.7  303000.0
# 114   January 11, 2019 (United States)    7.1   31000.0
# 24     October 5, 2018 (United States)    7.6  350000.0
# 210     March 15, 2019 (United States)    6.0   51000.0
# 183      June 21, 2019 (United States)    7.7  217000.0
# ..                                 ...    ...       ...
# 251    August 23, 2019 (United States)    6.6    4100.0
# 146  February 22, 2019 (United States)    7.1   71000.0
# 51   November 21, 2018 (United States)    5.3   68000.0
# 134  December 13, 2019 (United States)    6.2    5900.0
# 75    October 26, 2018 (United States)    7.4   54000.0
#
#                   director             writer            star         country  \
# 10   Christopher McQuarrie       Bruce Geller      Tom Cruise   United States
# 114             Mimi Leder  Daniel Stiepleman  Felicity Jones   United States
# 24          Bradley Cooper          Eric Roth       Lady Gaga   United States
# 210           Rupert Wyatt       Erica Beeney    John Goodman   United States
# 183            Josh Cooley      John Lasseter       Tom Hanks   United States
# ..                     ...                ...             ...             ...
# 251          Alex Kendrick      Alex Kendrick   Alex Kendrick   United States
# 146       Stephen Merchant   Stephen Merchant  Dwayne Johnson  United Kingdom
# 51           Otto Bathurst       Ben Chandler   Taron Egerton   United States
# 134           Xavier Dolan       Xavier Dolan   Kit Harington          Canada
# 75              Jonah Hill         Jonah Hill    Sunny Suljic   United States
#
#           budget         gross                    company  runtime
# 10   178000000.0  7.916574e+08         Paramount Pictures    147.0
# 114   20000000.0  3.875590e+07           Alibaba Pictures    120.0
# 24    36000000.0  4.361889e+08      Warner Bros. Pictures    136.0
# 210   25000000.0  8.808611e+06                Participant    109.0
# 183  200000000.0  1.073395e+09    Pixar Animation Studios    100.0
# ..           ...           ...                        ...      ...
# 251    5000000.0  3.802610e+07               Affirm Films    119.0
# 146   11000000.0  4.081192e+07  Metro-Goldwyn-Mayer (MGM)    108.0
# 51   100000000.0  8.649305e+07       Summit Entertainment    116.0
# 134   35000000.0  3.326364e+06                 Lyla Films    123.0
# 75    10000000.0  9.303022e+06                        A24     85.0
#
# [82 rows x 15 columns]
#
# Jumlah sample per genre:
#  genre
# Action       26
# Comedy       14
# Drama        11
# Biography     9
# Animation     7
# Adventure     6
# Horror        4
# Crime         4
# Fantasy       1
# Name: count, dtype: int64

# %% [markdown]
# AMBIL 30 DATA TERATAS DARI HASIL SAMPLING

# %%
sample_30 = stratified_sample.head(30)
print("\n30 Data Teratas Hasil Stratified Sampling:\n",
      sample_30[["name", "genre", "budget"]])
# Out:
# 30 Data Teratas Hasil Stratified Sampling:
#                                        name      genre       budget
# 10           Mission: Impossible - Fallout     Action  178000000.0
# 114                    On the Basis of Sex  Biography   20000000.0
# 24                          A Star Is Born      Drama   36000000.0
# 210                          Captive State     Action   25000000.0
# 183                            Toy Story 4  Animation  200000000.0
# 198                   Annabelle Comes Home     Horror   30000000.0
# 205              Pokémon Detective Pikachu     Action  150000000.0
# 20                   Under the Silver Lake      Crime    8500000.0
# 223                             The Hustle     Comedy   21000000.0
# 150                              Yesterday     Comedy   26000000.0
# 182                               Hustlers     Comedy   20000000.0
# 26                              Death Wish     Action   30000000.0
# 9        Spider-Man: Into the Spider-Verse  Animation   90000000.0
# 140                                    Kin     Action   30000000.0
# 161                                   1917      Drama   95000000.0
# 3                        Bohemian Rhapsody  Biography   52000000.0
# 64                                 Upgrade     Action    5000000.0
# 152      John Wick: Chapter 3 - Parabellum     Action   75000000.0
# 254                                   K-12    Fantasy    5000000.0
# 73                                Creed II      Drama   50000000.0
# 29                            Eighth Grade     Comedy    2000000.0
# 59   Hotel Transylvania 3: Summer Vacation  Animation   80000000.0
# 25             Mamma Mia! Here We Go Again     Comedy   75000000.0
# 220      The Lego Movie 2: The Second Part  Animation   99000000.0
# 247                           Breakthrough  Biography   14000000.0
# 149                                  Joker      Crime   55000000.0
# 39                         The First Purge     Action   13000000.0
# 87                           Hotel Artemis     Action   15000000.0
# 221                           Child's Play      Drama   10000000.0
# 52                           Beautiful Boy  Biography   25000000.0

# %% [markdown]
# ESTIMASI RATA-RATA POPULASI BUDGET FILM Waktu Pelayanan CS

# %%
import scipy.stats as stats
import math

# SKENARIO 1: WAKTU PELAYANAN CS (30 pelanggan)
# =========================================================

x_bar = 15          # rata-rata waktu pelayanan (menit)
s = 2.3             # standar deviasi sample
n = 30              # jumlah sample (pelanggan)
confidence_level = 0.95

alpha = (1 - confidence_level)
df = n - 1
standard_error = s / math.sqrt(n)
critical_t = stats.t.ppf(1 - alpha / 2, df)
margin_of_error = critical_t * standard_error

lower_bound = x_bar - margin_of_error
upper_bound = x_bar + margin_of_error

print("=== Skenario 1: Waktu Pelayanan CS ===")
print("Critical t-value: {:.3f}".format(critical_t))
print("Margin of Error: {:.3f}".format(margin_of_error))
print("Confidence Interval: [{:.3f}, {:.3f}]".format(lower_bound, upper_bound))
print("The {:.1%} confidence interval for the population mean is:".format(confidence_level))
print("between {:.3f} and {:.3f}".format(lower_bound, upper_bound))
print()
# Out:
# === Skenario 1: Waktu Pelayanan CS ===
# Critical t-value: 2.045
# Margin of Error: 0.859
# Confidence Interval: [14.141, 15.859]
# The 95.0% confidence interval for the population mean is:
# between 14.141 and 15.859

# %% [markdown]
# Estimasi Rata-rata Populasi Gaji Karyawan

# %%
x_bar = 2.5         # rata-rata gaji (dalam juta rupiah)
s = 0.26            # standar deviasi sample
n = 25              # jumlah sample (karyawan)
confidence_level = 0.95

alpha = (1 - confidence_level)
df = n - 1
standard_error = s / math.sqrt(n)
critical_t = stats.t.ppf(1 - alpha / 2, df)
margin_of_error = critical_t * standard_error

lower_bound = x_bar - margin_of_error
upper_bound = x_bar + margin_of_error

print("=== Skenario 2: Gaji Karyawan ===")
print("Critical t-value: {:.3f}".format(critical_t))
print("Margin of Error: {:.3f}".format(margin_of_error))
print("Confidence Interval: [{:.3f}, {:.3f}]".format(lower_bound, upper_bound))
print("The {:.1%} confidence interval for the population mean is:".format(confidence_level))
print("between {:.3f} and {:.3f}".format(lower_bound, upper_bound))
# Out:
# === Skenario 2: Gaji Karyawan ===
# Critical t-value: 2.064
# Margin of Error: 0.107
# Confidence Interval: [2.393, 2.607]
# The 95.0% confidence interval for the population mean is:
# between 2.393 and 2.607
